# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv(dotenv_path='../.env')

# Verify that the OpenAI API key is loaded
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print("✅ OpenAI API key loaded successfully.")
else:
    print("❌ Failed to load OpenAI API key. Please check your .env file.")
    print("Make sure your .env file contains: OPENAI_API_KEY=your_key_here")
# Out:
# ✅ OpenAI API key loaded successfully.

# %%
import os
from openai import OpenAI

client = OpenAI(api_key=openai_api_key)

# Use your converted file (.ogg or .wav)
audio_path = "./audios/audio.ogg"

with open(audio_path, "rb") as f:
    response = client.audio.transcriptions.create(
        model="gpt-4o-mini-transcribe",  # or "whisper-1"
        file=f,
        language="pt"  # optional hint for Portuguese
    )

# Print transcription
print(response.text)

# Save to text file
output_path = audio_path.replace(".ogg", ".txt").replace(".wav", ".txt")
with open(output_path, "w", encoding="utf-8") as txt_file:
    txt_file.write(response.text)

print(f"✅ Transcription saved to: {output_path}")
# Out:
# Essas crianças não dão folga, tava aqui te mandando áudio, aí o Arthur já pegou a Amy no colo e saiu andando, subindo escada. Aí cai, cai juntos, os dois se lascam, tá eu na UPA daqui a pouco. Isso não pode tirar o casaco, filho. Tá frio. Isso, papai tá de casaco. Tô não, mas... Ai, caraca, cara. É isso, cara. Esse filho é loucura. Mas é um lance completamente diferente. Deixa eu te falar. No Arthur, tipo... Arthur foi bebê, a gente cuidava dele, cresceu, paz, tranquilo. Quer dizer, ele não era tranquilo, mas a gente aprende a lidar com a criança e tal, e depois já pega os macetes. E é uma criança só, então você só tem que ficar de olho em uma criança. Só que duas crianças, cara. É uma correndo, que é bebê, não sabe nada das coisas, aí fica correndo para cima e para baixo igual doido. Aí o outro que também é bem parafusado dos juízos fica correndo mais do que o outro. Aí o outro quer ir atrás, aí os dois se lascam. E aí tá você no final do dia no hospital com os dois. Depois eu vou t
# ...
